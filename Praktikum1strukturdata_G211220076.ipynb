# %%
# Buat list untuk menampung nama-nama teman
my_friends = ["nando", "umar", "supar", "amir","Adam"]
print (my_friends[3])
print ("isi my_friends indeks ke3 adalah:{}".format(my_friends[3]) )
print ( "semua teman: ada {} orang".format(len(my_friends)) )
for i in my_friends : print (i)
# Out:
# amir
# isi my_friends indeks ke3 adalah:amir
# semua teman: ada 5 orang
# nando
# umar
# supar
# amir
# Adam

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
